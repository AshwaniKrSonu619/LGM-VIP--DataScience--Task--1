# %% [markdown]
# <a href="https://colab.research.google.com/github/OpAshwani/LGM-VIP--DataScience--Task--1/blob/main/Image_to_Pencil_Sketch_with_Pyhton.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Image to pencil Sketch with Python
#Task 1
#LGM(VIP)Data Science

from google.colab.patches import cv2_imshow
 
import cv2

img = cv2.imread("butterfly.jpg")

cv2_imshow(img)
# Out:
# <PIL.Image.Image image mode=RGB size=807x730 at 0x7FF1E8A37CD0>

# %%
img_gray = cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)

cv2_imshow(img_gray)
# Out:
# <PIL.Image.Image image mode=L size=807x730 at 0x7FF1D7B85A10>

# %%
img_invert = cv2.bitwise_not(img_gray)

cv2_imshow(img_invert)
# Out:
# <PIL.Image.Image image mode=L size=807x730 at 0x7FF1D93F73D0>

# %%
img_smoothing = cv2.GaussianBlur(img_invert, (21, 21),sigmaX=0, sigmaY=0)

cv2_imshow(img_smoothing)
# Out:
# <PIL.Image.Image image mode=L size=807x730 at 0x7FF1D9458D10>

# %%
def dodgeV2(x, y):
    return cv2.divide(x, 255 - y, scale=256)

# %%
final_img = dodgeV2(img_gray, img_smoothing)

cv2_imshow(final_img)
# Out:
# <PIL.Image.Image image mode=L size=807x730 at 0x7FF1D9458B50>
